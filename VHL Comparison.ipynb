# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install RISparser

import os
import json
from pprint import pprint
from RISparser import readris
ris_file = 'mendeley_vhl.ris'
json_file = 'mendeley_vhl.json'
out_file = "mendeley_unimported.json"

# %%
#ALL RIS entries, with the issn serial being the unique key
ris_entries = {}
with open(ris_file, 'r') as bibliography_file:
    entries = readris(bibliography_file)
    
    for entry in entries:        
        serial= entry["issn"]
        ris_entries[serial] = entry

# %%
ris_entries
# Out:
# {'2405-4569': {'type_of_reference': 'JOUR',
# ...

# %%
#ALL json entries, with the issn serial being the unique key
json_entries = {}
with open(json_file, 'r') as bibliography_file:
    entries = json.load(bibliography_file)
    
    for entry in entries:    
        serial= entry["identifiers"]["issn"]
        json_entries[serial] = entry

# %%
print((json_entries.keys()))
print((ris_entries.keys()))
# Out:
# dict_keys(['1671-167X', '0065-2598 2214-8019', '1573-7373', '1468-6244', '2041-1723', '1473-7140 1744-8328', '0020-7136 1097-0215', '1097-0142', '2160-1836', '2468-8681 2468-8673', '2049-9450', '1553-7358', '2203-5826', '2001-0370', '1569-9056 1878-1500', '1525-1578 1943-7811', '1472-4146', '0006-4971', '1942-0994', '1573-7292', '1573-4935', '2073-4409', '1938-0682', '2523-3785 2523-3793', '0012-1606 1095-564X', '2230-8210', '2045-2322', '0302-2838 1873-7560', '1365-2559', '0144-8463 1573-4935', '1941-6628 1941-6636', '1476-5594', '0019-509X 1998-4774', '2405-5808', '1464-3391', '1532-2548', '0730-2312 1097-4644', '1098-3600 1530-0366', '1558-8238', '2168-6157', '1838-7640', '1477-9137', '1097-4547', '1664-2295', '1470-8728', '0305-1048 1362-4962', '1433-0385', '2076-3271', '2296-634X', '1878-0849', '1873-4596', '2234-943X', '1351-0088 1479-6821', '1522-1563', '1003-9406', '2056-7944', '0300-0605 1473-2300', '2314-436X 2314-4378', '1527-3792', '2049-3614', '1769-7212 1878-0849', '199
# ...

# %%
print(len(json_entries.keys()))
print(len(ris_entries.keys()))
# Out:
# 104
# 155

# %%
json_set = set(json_entries.keys())
ris_set = set(ris_entries.keys())

#finding which serials are not inside the json set
json_extras = json_set.difference(ris_set)
ris_extras = ris_set.difference(json_set)
print(json_extras)
print(ris_extras)
# Out:
# set()
# {'2379-3708', '2188-4226', '1538-8514', '2363-8915', '1873-2496', '1098-5514', '1477-092X', '1759-4820', '2329-0501', '1540-7586', '1007-8738', '1879-260X', '1530-0366', '2296-2360', '1475-2867', '0006-3002', '0046-8177 1532-8392', '1533-4058', '1097-4172', '0918-5739', '1474-5488', '1949-2553', '1433-8726', '1524-4571', '1535-5667', '1520-4804', '1791-2423', '2077-0383', '1744-8042', '0970-9371', '0734-7332 1540-7586', '1539-7262', '1878-5875', '2211-1247', '2366-0058', '2235-3186', '1875-9157', '1523-7834', '2051-5960', '1756-8927', '0022-538X 1098-5514', '1527-7755', '1558-4488', '1934-6638', '1476-5403', '1936-0568', '1365-2168', '1479-6821', '1471-2350', '2227-9059', '1528-0020'}

# %%
out_set = [ris_entries[key] for key in ris_extras]

# %%
with open(out_file, 'w') as bibliography_file:
    json.dump(out_set, bibliography_file)
